# %%
## 다중 선형 회귀
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler



df = pd.read_csv("./data/ozone.csv")

# 데이터 정규화 

# 머신 러닝
x_data = df[["Solar.R", "Wind", "Temp"]]
x_data = MinMaxScaler().fit_transform(x_data)
y_data = df["Ozone"].values.reshape(-1,1)
y_data = MinMaxScaler().fit_transform(y_data)

### 생략

print(x_data)

# %%
## 지도 학습
## -1. linear regression (선형회귀)
## 단순선형회귀 (simple linear regression)

## 다중선형회귀 (multiple linear regression)

## 2. logistic regression(binary classification)
## -> 기반
## 알고리즘 중 가장 보편화 된 정확한 알고리즘
## 이메일 ㅅ팸인지 아닌지를 판별
## 내일의 주가 오를지 떨어질지 판별
## 신용카드 사용시 도난카드 시 아닌지를 판별
## y label 이 0 혹은 1 (True False)
## 머신러닝 결과는 확률로 나타나요!
## 0 ~ 1 사이의 값 출력
## 일반적ㅇ로 0.5 이상이면 1로 간주, 0.5 미만이면 0으로 간주
## x(시간) y(시험결과)
## 1          Fail(0) => 15
## 2          Fail(0) => 20
## 5          Fail(0) => 56
## 8          Pass(1) => 85
## 10         Pass(1) => 93
## 20         Pass(1)
# linear regress로 학습한 후 7시간 공부한 결과를 알아봄?!
import tensorflow as tf

x_data = [1,2,5,8,10,20]
y_data = [0,0,0,1,1,1]

x = tf.placeholder(dtype=tf.float32)
y = tf.placeholder(dtype=tf.float32)

W = tf.Variable(tf.random_normal([1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

H = W * x + b
cost = tf.reduce_mean(tf.square(H-y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(30000):
    _, cost_val = sess.run([train, cost], feed_dict={ x : x_data,
                                                      y : y_data})
    if step % 300 == 0:
        print("cost val : {}".format(cost_val))

predict = sess.run(H, feed_dict={x : 7}) # 0.503 => 0.5 보다 ㅋ면 합격

print(predict)
# Out:
# cost val : 5.999608039855957
# cost val : 0.06554403901100159
# cost val : 0.04414895549416542
# cost val : 0.0435544028878212
# cost val : 0.043537892401218414
# cost val : 0.043537434190511703
# cost val : 0.04353741556406021
# cost val : 0.04353741556406021
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# cost val : 0.04353741928935051
# ...
